# %% [markdown]
# **Import the libraries**

# %%
# import numpy, pandas and matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Load the dataset**

# %%
# load the CancerDataset.csv file
df=pd.read_csv('CancerDataset.csv')

# %% [markdown]
# Use **df.head(n)** to display the first n rows of the dataframe.

# %%
df.head(2)
# Out:
#    TumorSize  TumorDensity  CancerDetected
# 0         19         19000               0
# 1         35         20000               0

# %% [markdown]
# Use **df.tail(n)** to display the last n rows of the dataframe.

# %%
df.tail(2)
# Out:
#      TumorSize  TumorDensity  CancerDetected
# 398         36         33000               0
# 399         49         36000               1

# %%
df.shape
# Out:
# (400, 3)

# %% [markdown]
# **Visualize the data**
# A dataframe can be filterd using Boolean Indexing.
#
# To filter all the rows that have CancerDetected as 1, we can apply the filter as **df[df.CancerDetected == 1]**
# To filter all the rows that have CancerDetected as 0, we can apply the filter as **df[df.CancerDetected == 0]**

# %%
cancer_data = df[df.CancerDetected == 1]
non_cancer_data = df[df.CancerDetected == 0]

# %%
cancer_data
# Out:
#      TumorSize  TumorDensity  CancerDetected
# 7           32        150000               1
# 16          47         25000               1
# 17          45         26000               1
# 18          46         28000               1
# 19          48         29000               1
# ..         ...           ...             ...
# 393         60         42000               1
# 395         46         41000               1
# 396         51         23000               1
# 397         50         20000               1
# 399         49         36000               1
#
# [143 rows x 3 columns]

# %%
non_cancer_data
# Out:
#      TumorSize  TumorDensity  CancerDetected
# 0           19         19000               0
# 1           35         20000               0
# 2           26         43000               0
# 3           27         57000               0
# 4           19         76000               0
# ..         ...           ...             ...
# 377         42         53000               0
# 380         42         64000               0
# 387         39         71000               0
# 394         39         59000               0
# 398         36         33000               0
#
# [257 rows x 3 columns]

# %%
#Plot the scatter diagram
plt.scatter(cancer_data.TumorSize, cancer_data.TumorDensity, color='red')
plt.scatter(non_cancer_data.TumorSize, non_cancer_data.TumorDensity, color='green')
plt.xlabel('Tumor Size')
plt.ylabel('Tumor Density')
# Out:
# Text(0, 0.5, 'Tumor Density')

# %% [markdown]
# **Split the dataset into X and y**
# ***X*** is the input feature (years of exp) and ***y*** is the target variable that we are trying to predict (salary)

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

X.shape, y.shape
# Out:
# ((400, 2), (400,))

# %% [markdown]
# **Splitting the dataset into the Training set and Test set**

# %%
# import train_test_split from sklearn.model_selection and train the dataset to train and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((320, 2), (320,), (80, 2), (80,))

# %% [markdown]
# **Feature Scaling**
# Feature scaling is a data preprocessing technique that involves transforming the values of features or variables in a dataset to a similar scale.
# This is done to ensure that all features contribute equally to the model and to prevent features with larger values from dominating the model.
#
# Feature scaling is essential when working with datasets where the features have different ranges, units of measurement, or orders of magnitude.
#
# Common feature scaling techniques include standardization, normalization, and min-max scaling.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train) # note that we apply both fit and transform only to the training data
X_test = sc.transform(X_test) # note here that w are only applying the transform function here, and not the fit function

# %%
print(X_train)
print(X_test)
# Out:
# [[ 0.35561319  1.07367237]
#  [ 1.87163281 -0.66256196]
#  [ 0.07135952 -0.80487625]
#  [-1.91841622 -0.52024767]
#  [-1.72891377  0.33363806]
#  [ 0.7346181  -0.83333911]
#  [-0.30764539  0.58980378]
#  [ 0.63986687  0.24824949]
#  [-0.30764539 -1.28874484]
#  [-1.63416255  0.04900948]
#  [-0.49714784 -0.54871053]
#  [-1.91841622 -0.06484195]
#  [-0.21289416 -0.20715624]
#  [ 1.58737913  1.69985524]
#  [ 0.45036442  1.67139238]
#  [ 1.4926279  -0.00791623]
#  [-1.53941132 -0.20715624]
#  [-1.06565519  0.39056378]
#  [ 0.63986687  1.7283181 ]
#  [ 1.01887177  2.01294668]
#  [ 1.87163281  2.09833525]
#  [-1.16040642 -1.54491056]
#  [ 0.26086197 -1.14643055]
#  [-1.16040642 -1.14643055]
#  [ 0.35561319 -0.49178482]
#  [ 1.96638403 -0.80487625]
#  [ 0.07135952  0.02054663]
#  [-0.78140151  1.30137523]
#  [-1.823665   -1.26028198]
#  [-0.59189906  1.84216953]
#  [ 1.01887177 -0.89026483]
#  [ 0.82936932 -1.43105913]
#  [ 0.35561319 -0.15023052]
#  [ 0.35561319 -0.46332196]
#  [ 0.07135952  0.02054663]
#  [ 0.07135952  1.81370667]
#  [ 1.4926279   1.07367237]
#  [ 0.63986687 -1.37413341]
#  [-0.11814293  0.1059352 ]
#  [ 0.26086197  0.04900948]
#  [-0.49714784  1.21598666]
#  [ 0.07135952  1.47215238]
#  [ 0.54511565 -0.89026483]
#  [-0.11814293 -0.37793339]
#  [-1.34990887 -0.34947053]
#  [ 0.82936932 -1.03257912]
#  [-0.30764539 -0.49178482]
#  [ 1.39787668  2.06987239]
#  [-0.87615274  2.21218668]
#  [ 1.30312545  2.2691124 ]
#  [ 2.06113526  0.36210092]
#  [-0.97090397 -0.32100767]
#  [-0.49714784 -0.03637909]
#  [ 0.7346181  -1.08950483]
#  [-0.49714784 -0.7764134 ]
#  [-0.30764539 -0.91872769]
#  [ 0.92412055 -1.06104197]
#  [-1.06565519  0.53287807]
#  [ 0.07135952  0.07747234]
#  [ 0.82936932  1.21598666]
#  [ 0.92412055  0.1059352 ]
#  [-0.87615274 -0.7764134 ]
#  [ 0.07135952  0.73211807]
#  [-0.11814293 -0.00791623]
#  [-0.30764539  0.13439806]
#  [-0.78140151  0.53287807]
#  [ 1.96638403  0.16286092]
#  [ 1.01887177  0.50441521]
#  [-0.78140151  0.24824949]
#  [ 0.82936932 -1.14643055]
#  [ 0.35561319 -0.17869338]
#  [-0.87615274  0.13439806]
#  [ 1.113623   -0.74795054]
#  [ 0.7346181  -0.32100767]
#  [ 0.92412055  0.73211807]
#  [-0.49714784 -1.20335626]
#  [ 0.07135952  1.81370667]
#  [-0.30764539  0.04900948]
#  [ 0.82936932 -1.28874484]
#  [ 1.96638403  1.69985524]
#  [ 1.58737913 -0.89026483]
#  [ 0.82936932 -1.34567055]
#  [ 1.39787668  0.95982094]
#  [-0.11814293  0.24824949]
#  [-1.16040642  0.27671235]
#  [-1.34990887 -0.4348591 ]
#  [ 0.26086197  0.24824949]
#  [ 0.16611074  0.13439806]
#  [-1.06565519 -0.34947053]
#  [-0.02339171 -0.32100767]
#  [-0.11814293 -0.4348591 ]
#  [ 2.06113526 -0.69102482]
#  [ 1.01887177 -0.15023052]
#  [-0.30764539  0.50441521]
#  [-0.97090397 -1.08950483]
#  [-0.68665029 -1.57337342]
#  [-1.823665   -1.28874484]
#  [-0.21289416 -0.29254481]
#  [-0.59189906  0.44748949]
#  [-1.16040642  1.35830095]
#  [-0.11814293  0.04900948]
#  [ 0.07135952 -0.26408195]
#  [ 0.07135952  1.01674665]
#  [ 0.92412055  1.3867638 ]
#  [ 0.26086197  0.04900948]
#  [-0.30764539 -0.4348591 ]
#  [ 0.26086197  0.04900948]
#  [-0.02339171 -0.4348591 ]
#  [-0.30764539  0.24824949]
#  [-0.97090397  0.47595235]
#  [-0.11814293 -0.49178482]
#  [ 0.54511565  1.95602096]
#  [-0.87615274 -0.26408195]
#  [-1.25515764  0.27671235]
#  [ 0.7346181  -1.20335626]
#  [ 0.63986687 -1.26028198]
#  [ 0.82936932 -0.66256196]
#  [ 1.30312545  1.24444952]
#  [-1.34990887  0.39056378]
#  [ 0.16611074 -0.32100767]
#  [-0.68665029  0.1059352 ]
#  [ 2.06113526 -1.03257912]
#  [-1.06565519 -0.46332196]
#  [ 0.26086197  0.27671235]
#  [-0.68665029 -0.06484195]
#  [ 0.35561319  0.27671235]
#  [-1.16040642 -0.7764134 ]
#  [-0.68665029  0.53287807]
#  [-0.40239661  1.1875238 ]
#  [-1.823665    0.16286092]
#  [-0.30764539 -0.34947053]
#  [-1.72891377  0.44748949]
#  [-0.97090397  0.24824949]
#  [ 1.77688158  1.47215238]
#  [-1.53941132 -1.48798484]
#  [-0.21289416 -1.06104197]
#  [-0.68665029  0.02054663]
#  [-0.97090397 -0.4348591 ]
#  [ 1.30312545 -0.91872769]
#  [ 1.39787668 -1.03257912]
#  [-0.21289416 -0.57717339]
#  [-1.34990887 -1.08950483]
#  [ 0.7346181   0.24824949]
#  [-1.823665   -0.00791623]
#  [-1.06565519 -1.11796769]
#  [-0.30764539 -0.29254481]
#  [ 0.16611074  1.04520951]
#  [-1.63416255 -1.54491056]
#  [-0.30764539  0.19132377]
#  [ 0.92412055  1.9275581 ]
#  [-0.40239661  1.27291237]
#  [ 0.35561319  0.07747234]]

# %% [markdown]
# **Training the Logistic Regression model on the Training set**

# %%
#LogisticRegression
# Load the LogisticRegression from sklearn.linear_model and fit the data
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Predicting the Test set results**

# %%
# Make predictions with test data
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Evaluating the model
# **Accuracy**
# Accuracy is the percentage of the predictions that are correct

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.875

# %% [markdown]
# **Confusion Matrix**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[57  6]
#  [ 4 13]]

# %%
import seaborn as sns
sns.heatmap(cm, annot=True)
plt.xlabel('Actual Class')
plt.ylabel('Predicted Class')
# Out:
# Text(50.722222222222214, 0.5, 'Predicted Class')
